# %%
x = "55"
if x<55:
    print('yes')
else:
    print('Inappropriate result')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-758290bb9ce2> in <module>
#       1 x = "55"
# ----> 2 if x<55:
#       3     print('yes')
#       4 else:
#       5     print('Inappropriate result')
#
# TypeError: '<' not supported between instances of 'str' and 'int'

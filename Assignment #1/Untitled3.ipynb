# %%
print("Hello World");
# Out:
# Hello World

# %%
percent=-33
if percent<0:
    print('Not Accepted negative percentage')
elif percent>100:
    print('Percentage should be under 100')
elif percent<100 and percent>80:
    print('Grade A+')
elif percent<80 and percent>70:
    print('Grade A')
elif percent<70 and percent>60:
    print('Grade B')
elif percent<60 and percent>50:
    print('Grade C')
elif percent<50 and percent>40:
    print('Grade D')
elif percent<40 and percent>33:
    print('Grade E')
elif percent<33 and percent>0:
    print('Fail')
# Out:
# Not Accepted negative percentage

# %%
percent=-33
if percent<0:
    print('Not Accepted negative percentage')
elif percent>100:
    print('Percentage should be under 100')
elif percent<100 and percent>80:
    print('Grade A+')
elif percent<80 and percent>70:
    print('Grade A')
elif percent<70 and percent>60:
    print('Grade B')
elif percent<60 and percent>50:
    print('Grade C')
elif percent<50 and percent>40:
    print('Grade D')
elif percent<40 and percent>33:
    print('Grade E')
elif percent<33 and percent>0:
    print('Fail')
# Out:
# Not Accepted negative percentage

# %%
percent=-33
if percent<0:
    print('Not Accepted negative percentage')
elif percent == 0:
    print('Percentage should not be zero')
elif percent>100:
    print('Percentage should be under 100')
elif percent<100 and percent>80:
    print('Grade A+')
elif percent<80 and percent>70:
    print('Grade A')
elif percent<70 and percent>60:
    print('Grade B')
elif percent<60 and percent>50:
    print('Grade C')
elif percent<50 and percent>40:
    print('Grade D')
elif percent<40 and percent>33:
    print('Grade E')
elif percent<33 and percent>0:
    print('Fail')
# Out:
# Not Accepted negative percentage

# %%
percent=0
if percent<0:
    print('Not Accepted negative percentage')
elif percent == 0:
    print('Percentage should not be zero')
elif percent>100:
    print('Percentage should be under 100')
elif percent<100 and percent>80:
    print('Grade A+')
elif percent<80 and percent>70:
    print('Grade A')
elif percent<70 and percent>60:
    print('Grade B')
elif percent<60 and percent>50:
    print('Grade C')
elif percent<50 and percent>40:
    print('Grade D')
elif percent<40 and percent>33:
    print('Grade E')
elif percent<33 and percent>0:
    print('Fail')
# Out:
# Percentage should not be zero

# %%
percent=101
if percent<0:
    print('Not Accepted negative percentage')
elif percent == 0:
    print('Percentage should not be zero')
elif percent>100:
    print('Percentage should be under 100')
elif percent<100 and percent>80:
    print('Grade A+')
elif percent<80 and percent>70:
    print('Grade A')
elif percent<70 and percent>60:
    print('Grade B')
elif percent<60 and percent>50:
    print('Grade C')
elif percent<50 and percent>40:
    print('Grade D')
elif percent<40 and percent>33:
    print('Grade E')
elif percent<33 and percent>0:
    print('Fail')
# Out:
# Percentage should be under 100

# %%
percent=55
if percent<0:
    print('Not Accepted negative percentage')
elif percent == 0:
    print('Percentage should not be zero')
elif percent>100:
    print('Percentage should be under 100')
elif percent<100 and percent>80:
    print('Grade A+')
elif percent<80 and percent>70:
    print('Grade A')
elif percent<70 and percent>60:
    print('Grade B')
elif percent<60 and percent>50:
    print('Grade C')
elif percent<50 and percent>40:
    print('Grade D')
elif percent<40 and percent>33:
    print('Grade E')
elif percent<33 and percent>0:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Fail

# %%
percent=80
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Inappropriate input

# %%
percent=-34
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Not Accepted 0 or negative percentage

# %%
percent=-33
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Not Accepted 0 or negative percentage

# %%
percent=0
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Not Accepted 0 or negative percentage

# %%
percent=101
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Percentage should be under 100

# %%
percent=100
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Percentage should be under 100

# %%
percent=32
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Fail

# %%
percent=33
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Grade E

# %%
percent=34
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Grade E

# %%
percent=39
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')
# Out:
# Grade E

# %%
percent=80
if percent<=0:
    print('Not Accepted 0 or negative percentage')
elif percent>=100:
    print('Percentage should be under 100')
elif percent<100 and percent>=80:
    print('Grade A+')
elif percent<80 and percent>=70:
    print('Grade A')
elif percent<70 and percent>=60:
    print('Grade B')
elif percent<60 and percent>=50:
    print('Grade C')
elif percent<50 and percent>=40:
    print('Grade D')
elif percent<40 and percent>=33:
    print('Grade E')
elif percent<33:
    print('Fail')
else:
    print('Inappropriate input')

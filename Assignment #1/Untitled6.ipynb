# %%
eng = 64;
isl = 67;
math = 76;
total = 300;
percent = ((eng+isl+math)/total)*100;
print(percent);
# Out:
# 0.69

# %%
eng = 64;
isl = 67;
math = 76;
total = 300;
percent = ((eng+isl+math)/total)*100;
print(percent);
# Out:
# 69.0

# %%
eng = 64;
isl = 67;
math = 76;
total = 300;
percent = ((eng+isl+math)/total)*100;
if percent<=0:
    print('Not Accepeted 0 or negative percentage');
elif percent>=100:
    print('Percentage should be under 100');
elif percent<100 and percent>=80:
    print('Your Grade is A+');
elif percent<80 and percent>=70:
    print('Your Grade is A');
elif percent<70 and percent>=60:
    print('Your Grade is B');
elif percent<60 and percent>=50:
    print('Your Grade is C');
elif percent<50 and percent>=40:
    print('Your Grade is D');
elif percent<40 and percent>=33:
    print('Your Grade is E');
elif percent<33:
    print('You are Fail');
else:
    print('Inappropriate input');
# Out:
# Your Grade is B
